# %%
import numpy as np
import pandas as pd
from copy import deepcopy

# %%
def euclidean(a,b, ax=1):
    return np.linalg.norm(a-b, axis=ax)

# %%
k = 3
X = pd.read_csv('kmeans.csv',index_col=False)
print(X)
# Out:
#     X1   X2
# 0  5.9  3.2
# 1  4.6  2.9
# 2  6.2  2.8
# 3  4.7  3.2
# 4  5.5  4.2
# 5  5.0  3.0
# 6  4.9  3.1
# 7  6.7  3.1
# 8  5.1  3.8
# 9  6.0  3.0

# %%
x1 = X['X1'].values
x2 = X['X2'].values
X = np.array(list(zip(x1, x2)))
print(X)
# Out:
# [[5.9 3.2]
#  [4.6 2.9]
#  [6.2 2.8]
#  [4.7 3.2]
#  [5.5 4.2]
#  [5.  3. ]
#  [4.9 3.1]
#  [6.7 3.1]
#  [5.1 3.8]
#  [6.  3. ]]

# %%
C_x = [6.2, 6.6 ,6.5]
C_y = [3.2, 3.7, 3.0]
Centroid = np.array(list(zip(C_x, C_y)), dtype=np.float32)
print("Initial Centroids")
print(Centroid.shape)
# Out:
# Initial Centroids
# (3, 2)

# %%
Centroid_old = np.zeros(Centroid.shape)
print(Centroid_old)
# Out:
# [[0. 0.]
#  [0. 0.]
#  [0. 0.]]

# %%
clusters = np.zeros(len(X))
print(clusters)
error = euclidean(Centroid, Centroid_old, None)
print(error)
# Out:
# [0. 0. 0. 0. 0.]
# 12.537144692236463

# %%
iterr = 0
    # Loop will run till the error becomes zero
while error != 0:
    # Assigning each value to its closest cluster
    iterr = iterr + 1
    for i in range(len(X)):
        #print(X[i])
        distances = euclidean(X[i], Centroid)
        #print(distances)
        cluster = np.argmin(distances)
        clusters[i] = cluster

    Centroid_old = deepcopy(Centroid)
        
    # Finding the new centroids by taking the Mean
    for p in range(k):
        points = [X[j] for j in range(len(X)) if clusters[j] == p]
        Centroid[p] = np.mean(points, axis=0)
    print(" Centre of the clusters after ", iterr," Iteration \n", Centroid)
    error = euclidean(Centroid, Centroid_old, None)
    print("Error  ... ",error)
# Out:
# /home/root1/anaconda3/lib/python3.7/site-packages/numpy/core/fromnumeric.py:3118: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /home/root1/anaconda3/lib/python3.7/site-packages/numpy/core/_methods.py:85: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
#  Centre of the clusters after  1  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  2  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  3  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  4  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  5  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  6  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  7  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  8  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  9  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  10  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  11  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  12  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  15  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  16  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  17  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  18  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  19  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  20  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  21  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  22  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  23  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  24  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  25  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  26  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  27  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  28  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  29  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  30  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  31  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  32  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  33  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  34  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  35  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  36  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  37  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  38  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  39  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  40  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  41  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  42  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  43  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  44  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  45  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  46  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  47  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  48  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  49  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  50  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  51  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  52  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  53  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  54  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  55  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  56  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  57  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  58  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  59  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  60  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  61  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  62  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  63  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  64  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  65  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  66  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  67  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  68  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  69  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  70  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  71  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  72  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  73  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  74  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  75  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  76  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  77  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  78  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  79  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  80  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  81  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  82  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  83  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  84  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  85  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  86  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  87  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  88  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  89  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  90  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  91  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  92  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  93  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  94  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  95  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  96  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after
Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  440  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  441  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  442  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  443  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  444  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  445  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  446  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  447  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  448  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  449  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  450  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  451  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  452  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  453  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  454  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  455  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  456  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  457  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  458  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  459  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  460  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  461  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  462  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  463  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  464  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  465  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  466  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  467  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  468  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  469  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  470  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  471  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  472  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  473  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  474  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  475  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  476  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  477  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  478  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  479  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  480  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  481  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  482  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  483  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  484  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  485  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  486  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  487  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  488  Iteration
#  [[nan nan]
# ...
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13992  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13993  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13994  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13995  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13996  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13997  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13998  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  13999  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14000  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14001  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14002  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14003  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14004  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14005  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14006  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14007  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14008  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14009  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14010  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14011  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14012  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14013  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14014  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14015  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14016  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14017  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14018  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14019  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14020  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14021  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14022  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14023  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14024  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14025  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14026  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14027  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14028  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14029  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14030  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14031  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14032  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14033  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14034  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14035  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14036  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14037  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14038  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14039  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14040  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14041  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14042  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14043  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14044  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14045  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14046  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14047  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14048  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14049  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14050  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14051  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14052  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14053  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14054  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14055  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14056  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14057  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14058  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14059  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14060  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14061  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14062  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14063  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14064  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14065  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14066  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14067  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14068  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14069  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14070  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14071  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14072  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14073  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14074  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14075  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14076  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14077  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14078  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14079  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14080  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14081  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14082  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14083  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14084  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14085  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14086  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14087  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14088  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14089  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14090  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14091  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14092  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14093  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14094  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14095  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14096  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14097  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14098  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14099  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14100  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14101  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14102  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14103  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14104  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14105  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14106  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14107  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14108  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14109  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14110  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14111  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14112  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14113  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14114  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14115  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14116  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14117  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14118  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14119  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14120  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14121  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14122  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14123  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14124  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14125  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14126  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14127  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14128  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14129  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14130  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14131  Iteration
#  [[1.4 2.4]
#  [nan nan]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14132  Iteration
#  [[nan nan]
#  [1.4 2.4]
#  [nan nan]]
# Error  ...  nan
#  Centre of the clusters after  14133  Iteration
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-54c8c944f43a> in <module>
#      17         points = [X[j] for j in range(len(X)) if clusters[j] == p]
#      18         Centroid[p] = np.mean(points, axis=0)
# ---> 19     print(" Centre of the clusters after ", iterr," Iteration \n", Centroid)
#      20     error = euclidean(Centroid, Centroid_old, None)
#      21     print("Error  ... ",error)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/arrayprint.py in _array_str_implementation(a, max_line_width, precision, suppress_small, array2string)
#    1514         return _guarded_str(np.ndarray.__getitem__(a, ()))
#    1515
# -> 1516     return array2string(a, max_line_width, precision, suppress_small, ' ', "")
#    1517
#    1518
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/arrayprint.py in array2string(a, max_line_width, precision, suppress_small, separator, prefix, style, formatter, threshold, edgeitems, sign, floatmode, suffix, **kwarg)
#     665     overrides = _make_options_dict(precision, threshold, edgeitems,
#     666                                    max_line_width, suppress_small, None, None,
# --> 667                                    sign, formatter, floatmode, legacy)
#     668     options = _format_options.copy()
#     669     options.update(overrides)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/core/arrayprint.py in _make_options_dict(precision, threshold, edgeitems, linewidth, suppress, nanstr, infstr, sign, formatter, floatmode, legacy)
#      72     """ make a dictionary out of the non-None arguments, plus sanity checks """
#      73
# ---> 74     options = {k: v for k, v in locals().items() if v is not None}
#      75
#      76     if suppress is not None:
#
# KeyboardInterrupt:

# %%
print(clusters)
# Out:
# [0. 0. 0. 0. 0.]
